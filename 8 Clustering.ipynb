# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_excel('EastWestAirlines.xlsx',sheet_name='data')

# %%
df
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
df=df.rename({'Award?':'Award'},axis=1)

# %%
df.drop('ID#',axis=1,inplace=True)

# %%
df.describe()
# Out:
#             Balance    Qual_miles    cc1_miles    cc2_miles    cc3_miles  \
# count  3.999000e+03   3999.000000  3999.000000  3999.000000  3999.000000
# mean   7.360133e+04    144.114529     2.059515     1.014504     1.012253
# std    1.007757e+05    773.663804     1.376919     0.147650     0.195241
# min    0.000000e+00      0.000000     1.000000     1.000000     1.000000
# 25%    1.852750e+04      0.000000     1.000000     1.000000     1.000000
# 50%    4.309700e+04      0.000000     1.000000     1.000000     1.000000
# 75%    9.240400e+04      0.000000     3.000000     1.000000     1.000000
# max    1.704838e+06  11148.000000     5.000000     3.000000     5.000000
#
#          Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# count    3999.000000   3999.00000        3999.000000      3999.000000
# mean    17144.846212     11.60190         460.055764         1.373593
# std     24150.967826      9.60381        1400.209171         3.793172
# ...

# %%
df.head()
# Out:
#    Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    28143           0          1          1          1          174
# 1    19244           0          1          1          1          215
# 2    41354           0          1          1          1         4123
# 3    14776           0          1          1          1          500
# 4    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award
# 0            1                  0                0               7000      0
# 1            2                  0                0               6968      0
# 2            4                  0                0               7034      0
# 3            1                  0                0               6952      0
# 4           26               2077                4               6935      1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Balance            3999 non-null   int64
#  1   Qual_miles         3999 non-null   int64
#  2   cc1_miles          3999 non-null   int64
#  3   cc2_miles          3999 non-null   int64
#  4   cc3_miles          3999 non-null   int64
#  5   Bonus_miles        3999 non-null   int64
#  6   Bonus_trans        3999 non-null   int64
#  7   Flight_miles_12mo  3999 non-null   int64
#  8   Flight_trans_12    3999 non-null   int64
#  9   Days_since_enroll  3999 non-null   int64
#  10  Award              3999 non-null   int64
# dtypes: int64(11)
# memory usage: 343.8 KB

# %%
df.isnull().sum()
# Out:
# Balance              0
# Qual_miles           0
# cc1_miles            0
# cc2_miles            0
# cc3_miles            0
# Bonus_miles          0
# Bonus_trans          0
# Flight_miles_12mo    0
# Flight_trans_12      0
# Days_since_enroll    0
# Award                0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.corr()
# Out:
#                     Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# Balance            1.000000    0.108722   0.338344  -0.008804   0.035243
# Qual_miles         0.108722    1.000000   0.007931  -0.013923  -0.007779
# cc1_miles          0.338344    0.007931   1.000000  -0.068223   0.060555
# cc2_miles         -0.008804   -0.013923  -0.068223   1.000000  -0.006166
# cc3_miles          0.035243   -0.007779   0.060555  -0.006166   1.000000
# Bonus_miles        0.403487    0.031021   0.825200  -0.003969   0.204134
# Bonus_trans        0.324935    0.050725   0.608943   0.064399   0.097313
# Flight_miles_12mo  0.217551    0.126774   0.037370   0.010598  -0.001777
# Flight_trans_12    0.255700    0.144004   0.041333   0.028284  -0.001117
# Days_since_enroll  0.263129    0.017312   0.230849  -0.005807   0.010832
# Award              0.178494    0.095256   0.335457   0.005332   0.023484
#
#                    Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# ...

# %%
plt.figure(figsize=(15,10))
corr_matrix = df.corr()
corr_matrix = corr_matrix.dropna(axis=1, how='all').dropna(axis=0, how='all')
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.show()

# %%
plt.figure(figsize=(12,10))
df.boxplot()
plt.xticks(rotation = 90);

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
df1 = df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
sns.pairplot(df)
plt.show()

# %%
plt.figure(figsize=(15,15))
for i,column in enumerate(df.columns):
    plt.subplot(len(df.columns)//2+1,2,i+1)
    sns.histplot(df[column],kde=True)
    plt.title(f'{column}-Histogram')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(7,7))
Balance = df[['Award','Balance']].sort_values ('Balance',ascending = False)
ax =  sns.barplot(x = 'Award',y = 'Balance',data = Balance)
ax.set(xlabel = 'Award',ylabel = 'Balance')
plt.xticks(rotation = 90)
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
std_sca=StandardScaler()
df_new=std_sca.fit_transform(df)

# %% [markdown]
# ### K-Means
# ## Elbow_method

# %%
from sklearn.cluster import KMeans

# %%
from sklearn.metrics import silhouette_score

# %%
inertia=[]
for i in range(1,11):
    kmeans=KMeans(n_clusters=i)
    kmeans.fit(df_new)
    inertia.append(kmeans.inertia_)
print(inertia)
# Out:
# [43989.00000000001, 35409.516629861326, 30899.271221785584, 27154.600976484802, 23700.435800408562, 21089.728915838423, 18893.59434829801, 17374.386766245236, 16043.40242124884, 14729.73806359349]

# %%
plt.plot(range(1,11),inertia)
plt.xlabel('No_Of_Clusters')
plt.ylabel('inertia')
plt.title('Elbow_method',size=20)
# Out:
# Text(0.5, 1.0, 'Elbow_method')

# %%
output=[]
for i in range(2,11):
    labels=KMeans(n_clusters=i).fit(df_new).labels_
    score=silhouette_score(df,labels)
    output.append([i,score])
print(output)
# Out:
# [[2, 0.34333332585159393], [3, 0.2887001020680009], [4, 0.2770566537501412], [5, 0.12739020518208388], [6, 0.032504972996729185], [7, 0.017457028994327387], [8, -0.08676149921721842], [9, 0.03430884159927789], [10, -0.0925950238548523]]

# %%
cluster=KMeans(n_clusters=2)
labels=cluster.fit(df_new).labels_

# %%
labels
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int32)

# %%
df['kmeans_cluster']=labels

# %%
df.head()
# Out:
#    Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    28143           0          1          1          1          174
# 1    19244           0          1          1          1          215
# 2    41354           0          1          1          1         4123
# 3    14776           0          1          1          1          500
# 4    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award  \
# 0            1                  0                0               7000      0
# 1            2                  0                0               6968      0
# 2            4                  0                0               7034      0
# 3            1                  0                0               6952      0
# 4           26               2077                4               6935      1
#
#    kmeans_cluster
# 0               1
# 1               1
# 2               1
# ...

# %%
cluster.cluster_centers_
# Out:
# array([[ 0.5872949 ,  0.14721722,  1.12808718, -0.03055786,  0.1262273 ,
#          1.006859  ,  0.91514705,  0.36098026,  0.40187157,  0.39886897,
#          0.70065344],
#        [-0.28319891, -0.07098948, -0.54397384,  0.01473528, -0.06086794,
#         -0.48551652, -0.44129218, -0.17406794, -0.19378611, -0.19233822,
#         -0.33786143]])

# %%
df['kmeans_cluster'].value_counts()
# Out:
# kmeans_cluster
# 1    2697
# 0    1302
# Name: count, dtype: int64

# %% [markdown]
# ### Hiererchical Clustering

# %%
from sklearn.cluster import AgglomerativeClustering
import scipy.cluster.hierarchy as sch

# %%
dendrogram=sch.dendrogram(sch.linkage(df_new,method='ward'))

# %%
dendrogram=sch.dendrogram(sch.linkage(df_new,method='average'))

# %%
dendrogram=sch.dendrogram(sch.linkage(df_new,method='single'))

# %%
dendrogram=sch.dendrogram(sch.linkage(df_new,method='complete'))

# %%
output=[]
for i in range(2,11):
    labels=AgglomerativeClustering(n_clusters=i,linkage='complete').fit(df_new).labels_
    score=silhouette_score(df_new,labels)
    output.append([i,score])
print(output)
# Out:
# [[2, 0.8111134025692677], [3, 0.7760836053602842], [4, 0.5985727763092806], [5, 0.5625737661941762], [6, 0.5404241979396106], [7, 0.5418820074020084], [8, 0.5354664617626079], [9, 0.5313341704697034], [10, 0.41505057280945407]]

# %%
agg=AgglomerativeClustering(n_clusters=2,linkage='complete',affinity = 'euclidean')

# %%
cluster=agg.fit(df_new)

# %%
hierarchy_labels=cluster.labels_

# %%
silhouette_score(df_new,cluster.labels_)
# Out:
# 0.8111134025692677

# %%
df['hierar_labels']=hierarchy_labels

# %%
df.head()
# Out:
#    Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    28143           0          1          1          1          174
# 1    19244           0          1          1          1          215
# 2    41354           0          1          1          1         4123
# 3    14776           0          1          1          1          500
# 4    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award  \
# 0            1                  0                0               7000      0
# 1            2                  0                0               6968      0
# 2            4                  0                0               7034      0
# 3            1                  0                0               6952      0
# 4           26               2077                4               6935      1
#
#    kmeans_cluster  hierar_labels
# 0               1              0
# ...

# %%
# plotting with no of miles eligible for free flight and agglomerative clusterid 
plt.figure(figsize=(20,7))
Balance = df[['hierar_labels','Balance']].sort_values ('Balance',ascending = False)
ax =  sns.barplot(x = 'hierar_labels',y = 'Balance',data = Balance)
ax.set(xlabel = 'hierar_labels',ylabel = 'Balance')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ### DBSCAN

# %%
from sklearn.cluster import DBSCAN

# %%
output=[]
eps=[0.1,0.2,0.5,0.8,1.2,1.6]
min_samples=range(1,11)
for i in eps:
    for j in min_samples:
        labels=DBSCAN(eps=i,min_samples=j).fit(df_new).labels_
        score=silhouette_score(df_new,labels)
        output.append([i,j,score])
print(output)
# Out:
# [[0.1, 1, -0.021038216193662966], [0.1, 2, -0.49038229339647016], [0.1, 3, -0.4137794156232526], [0.1, 4, -0.32361181056810395], [0.1, 5, -0.3194616440468504], [0.1, 6, -0.32364864003039995], [0.1, 7, -0.2924275294117559], [0.1, 8, -0.29020171029784225], [0.1, 9, -0.29322159598613845], [0.1, 10, -0.28787330915642273], [0.2, 1, -0.12761535330982712], [0.2, 2, -0.5018226302722505], [0.2, 3, -0.5311203327416464], [0.2, 4, -0.5101427966864885], [0.2, 5, -0.4637282154062364], [0.2, 6, -0.3726615256879686], [0.2, 7, -0.26587503840086935], [0.2, 8, -0.26540792633817734], [0.2, 9, -0.2907484497912732], [0.2, 10, -0.06777923390507672], [0.5, 1, -0.2039353062332268], [0.5, 2, -0.22436165078450082], [0.5, 3, -0.11448578186172831], [0.5, 4, -0.10033744395215355], [0.5, 5, -0.0783475783174116], [0.5, 6, -0.08142145172839038], [0.5, 7, -0.10988563408744552], [0.5, 8, -0.09453806744796345], [0.5, 9, -0.10604753500343582], [0.5, 10, -0.09835626959249077], [0.8, 1, -0.3231988890889879], [0.8, 2, -0.2
# ...

# %%
a=pd.DataFrame(output)

# %%
a.iloc[:,2].max()
# Out:
# 0.2566601722143477

# %%
a[a[2]==0.2566601722143477]
# Out:
#       0  1        2
# 54  1.6  5  0.25666

# %%
cluster=DBSCAN(eps=1.6,min_samples=8).fit(df_new)

# %%
DBSCAN_labels=cluster.labels_

# %%
silhouette_score(df_new,DBSCAN_labels)
# Out:
# 0.2539954034187191

# %%
df['DBSCAN_labels']=DBSCAN_labels

# %%
df.head()
# Out:
#    Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    28143           0          1          1          1          174
# 1    19244           0          1          1          1          215
# 2    41354           0          1          1          1         4123
# 3    14776           0          1          1          1          500
# 4    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award  \
# 0            1                  0                0               7000      0
# 1            2                  0                0               6968      0
# 2            4                  0                0               7034      0
# 3            1                  0                0               6952      0
# 4           26               2077                4               6935      1
#
#    kmeans_cluster  hierar_labels  DBSCAN_labels
# ...
